# %% [markdown]
# # Questions

# %% [markdown]
# ## 1. a) All possible ways to put `n` cookies in `r` plates.
# ## 1. b) Simulate the probability if a fly lands randomly on one plate that it can eat a cookie

# %% [markdown]
# ## 2. You are given x points and the coordinates in the x axis. You are given an interval of length l. How many intervals of length l are needed to cover the points?

# %% [markdown]
# ## 3. You are given an unsorted array of integers possibly containing duplicates and 2 number x and y in the array. Find the minimum distance between x and y.
#
# ```
# example:
#  [3,4,5], 3, 5 -> 2
#  [3,6,1,4,7,2,0,3,0,1,7,6,4], 3,4 -> 3
# ```

# %% [markdown]
# ## 4. Build a topological sort of a DAG is one where for any edge (u,v), then u comes before v.
# ![image.png](attachment:4e728dcc-3a7b-4c76-814f-8e6e1b688a7a.png)
#
# ```
# DFS: 5,2,3,1,0,4
# TS: 5,4,0,2,3,1
# ```
