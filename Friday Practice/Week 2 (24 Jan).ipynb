# %% [markdown]
# # Questions

# %% [markdown]
# ## 1. Find the only number that does not repeat where every other number does once. In O(1) space complexity. Can you do it in O(O)?

# %% [markdown]
# ## 2. You are in Cambridge and you are admiring the Boston skyline. You have the top left and top rightcoordinates and height of the building. Compute the skyline (basically the points where the height changes)
# ### INPUT
# ![image.png](attachment:74dd6833-0b3a-4984-bffb-49b9a0aa1207.png)
# ### OUTPUT
# ![image.png](attachment:2461a394-0b66-4fa4-942e-fd79f7d4f12e.png)

# %% [markdown]
# ## 3. You're given 2 rectangles each with bottom left and top right coordinates ((r1, l1), (r2, l2)). Determine if they intersect

# %% [markdown]
# ## 4. You have N rectangles all parallel to the `X` and `Y` axes. Compute their total area. Note: Do not count area twice. Rectangle may intersect (overlap)
